# %%
import pandas as pd

df = pd.read_csv('Walmart.csv')
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
# Convert columns in date time format
df['Date'] = pd.to_datetime(df['Date'], format='%d-%m-%Y', errors='coerce')
df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-02-05    1643690.90             0        42.31       2.572
# 1         1 2010-02-12    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-03-05    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-10-05     733455.07             0        64.89       3.985
# 6432     45 2012-10-12     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   datetime64[ns]
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 402.3 KB

# %%
# Filtering in date time
df.loc[df['Date']>'2010-01-01']
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-02-05    1643690.90             0        42.31       2.572
# 1         1 2010-02-12    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-03-05    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-10-05     733455.07             0        64.89       3.985
# 6432     45 2012-10-12     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
df.loc[df["Date"]>'2010']
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-02-05    1643690.90             0        42.31       2.572
# 1         1 2010-02-12    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-03-05    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-10-05     733455.07             0        64.89       3.985
# 6432     45 2012-10-12     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
df.loc[df['Date']>='2010-05']
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 13        1 2010-05-07    1603955.12             0        72.55       2.835
# 14        1 2010-05-14    1494251.50             0        74.78       2.854
# 15        1 2010-05-21    1399662.07             0        76.44       2.826
# 16        1 2010-05-28    1432069.95             0        80.44       2.759
# 17        1 2010-06-04    1615524.71             0        80.69       2.705
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-10-05     733455.07             0        64.89       3.985
# 6432     45 2012-10-12     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# ...

# %%
df.loc[df["Date"]=='2012-10-12']
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 140       1 2012-10-12    1573072.81             0        62.99       3.601
# 283       2 2012-10-12    1900745.13             0        60.97       3.601
# 426       3 2012-10-12     410804.39             0        70.31       3.601
# 569       4 2012-10-12    2133026.07             0        57.11       3.603
# 712       5 2012-10-12     325345.41             0        66.24       3.601
# 855       6 2012-10-12    1459396.84             0        65.43       3.601
# 998       7 2012-10-12     503463.93             0        41.43       3.760
# 1141      8 2012-10-12     927511.99             0        55.03       3.601
# 1284      9 2012-10-12     558464.80             0        60.09       3.601
# 1427     10 2012-10-12    1713889.11             0        76.03       4.468
# 1570     11 2012-10-12    1311965.09             0        69.94       3.601
# ...

# %%
# Multiple condition in date
edf = df.loc[(df['Date']>='2010') & (df['Date']<'2011-01-01')]
edf
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-02-05    1643690.90             0        42.31       2.572
# 1         1 2010-02-12    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-03-05    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6335     45 2010-12-03     879244.90             0        40.93       3.046
# 6336     45 2010-12-10    1002364.34             0        30.54       3.109
# 6337     45 2010-12-17    1123282.85             0        30.51       3.140
# 6338     45 2010-12-24    1682862.03             0        30.59       3.141
# 6339     45 2010-12-31     679156.20             1        29.67       3.179
#
#              CPI  Unemployment
# ...

# %%
# sort Date
edf.sort_values('Date')
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-02-05    1643690.90             0        42.31       2.572
# 1430     11 2010-02-05    1528008.64             0        46.04       2.572
# 5005     36 2010-02-05     467546.74             0        45.97       2.545
# 1287     10 2010-02-05    2193048.75             0        54.34       2.962
# 5148     37 2010-02-05     536006.73             0        45.97       2.572
# ...     ...        ...           ...           ...          ...         ...
# 5481     39 2010-12-31    1230012.16             1        52.45       2.943
# 619       5 2010-12-31     298180.18             1        49.79       2.943
# 5052     36 2010-12-31     359310.65             1        52.88       2.949
# 1620     12 2010-12-31     891736.91             1        45.64       3.148
# 6339     45 2010-12-31     679156.20             1        29.67       3.179
#
#              CPI  Unemployment
# ...

# %%
# set date time as Index
edf = df.set_index('Date')
edf
# Out:
#             Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# Date
# 2010-02-05      1    1643690.90             0        42.31       2.572
# 2010-02-12      1    1641957.44             1        38.51       2.548
# 2010-02-19      1    1611968.17             0        39.93       2.514
# 2010-02-26      1    1409727.59             0        46.63       2.561
# 2010-03-05      1    1554806.68             0        46.50       2.625
# ...           ...           ...           ...          ...         ...
# 2012-09-28     45     713173.95             0        64.88       3.997
# 2012-10-05     45     733455.07             0        64.89       3.985
# 2012-10-12     45     734464.36             0        54.47       4.000
# 2012-10-19     45     718125.53             0        56.47       3.969
# 2012-10-26     45     760281.43             0        58.85       3.882
#
#                    CPI  Unemployment
# Date
# 2010-02-05  211.096358         8.106
# ...

# %%
# If we have set date as index, can perform filtering very easily 
edf['2010':'2011']
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_3928\2432609425.py:2: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   edf['2010':'2011']
#             Store  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# Date
# 2010-02-05      1    1643690.90             0        42.31       2.572
# 2010-02-12      1    1641957.44             1        38.51       2.548
# 2010-02-19      1    1611968.17             0        39.93       2.514
# 2010-02-26      1    1409727.59             0        46.63       2.561
# 2010-03-05      1    1554806.68             0        46.50       2.625
# ...           ...           ...           ...          ...         ...
# 2011-12-02     45     875699.81             0        50.19       3.452
# 2011-12-09     45     957155.31             0        46.57       3.415
# 2011-12-16     45    1078905.68             0        39.93       3.413
# ...

# %%
# Get day from date
df['day'] = df['Date'].dt.day
df[['Date', 'day']]
# Out:
#            Date  day
# 0    2010-02-05    5
# 1    2010-02-12   12
# 2    2010-02-19   19
# 3    2010-02-26   26
# 4    2010-03-05    5
# ...         ...  ...
# 6430 2012-09-28   28
# 6431 2012-10-05    5
# 6432 2012-10-12   12
# 6433 2012-10-19   19
# 6434 2012-10-26   26
#
# [6435 rows x 2 columns]

# %%
# get month from a month
df['month'] = df['Date'].dt.month
df[['Date', 'month']]
# Out:
#            Date  month
# 0    2010-02-05      2
# 1    2010-02-12      2
# 2    2010-02-19      2
# 3    2010-02-26      2
# 4    2010-03-05      3
# ...         ...    ...
# 6430 2012-09-28      9
# 6431 2012-10-05     10
# 6432 2012-10-12     10
# 6433 2012-10-19     10
# 6434 2012-10-26     10
#
# [6435 rows x 2 columns]
